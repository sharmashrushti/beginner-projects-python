# %% [markdown]
# <a href="https://colab.research.google.com/github/sharmashrushti/beginner-projects-python/blob/main/to_do_lists.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Simple To-Do List App

tasks = []

print("📝 Welcome to the To-Do List App!")

while True:
    print("\nChoose an option:")
    print("1. Add Task")
    print("2. View Tasks")
    print("3. Remove Task")
    print("4. Exit")

    choice = input("Enter your choice (1-4): ")

    # Add task
    if choice == "1":
        task = input("Enter the task: ")
        tasks.append(task)
        print("✅ Task added!")

    # View tasks
    elif choice == "2":
        if len(tasks) == 0:
            print("📭 No tasks in the list.")
        else:
            print("\n📋 Your Tasks:")
            for index, task in enumerate(tasks, start=1):
                print(f"{index}. {task}")

    # Remove task
    elif choice == "3":
        if len(tasks) == 0:
            print("📭 No tasks to remove.")
        else:
            print("\n📋 Your Tasks:")
            for index, task in enumerate(tasks, start=1):
                print(f"{index}. {task}")

            task_number = int(input("Enter task number to remove: "))

            if 1 <= task_number <= len(tasks):
                removed = tasks.pop(task_number - 1)
                print(f"🗑️ Removed: {removed}")
            else:
                print("❌ Invalid task number.")

    # Exit app
    elif choice == "4":
        print("👋 Goodbye!")
        break

    else:
        print("❌ Invalid choice. Please try again.")
# Out:
# 📝 Welcome to the To-Do List App!
#
# Choose an option:
# 1. Add Task
# 2. View Tasks
# 3. Remove Task
# 4. Exit
# Enter your choice (1-4): 1
# Enter the task: Review statistics
# ✅ Task added!
#
# Choose an option:
# 1. Add Task
# 2. View Tasks
# 3. Remove Task
# 4. Exit
# Enter your choice (1-4): 2
#
# 📋 Your Tasks:
# 1. Review statistics
#
# Choose an option:
# 1. Add Task
# 2. View Tasks
# 3. Remove Task
# 4. Exit
