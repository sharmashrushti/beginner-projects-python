# %% [markdown]
# <a href="https://colab.research.google.com/github/sharmashrushti/beginner-projects-python/blob/main/rock_paper_scissors.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# Choices for the game
choices = ["rock", "paper", "scissors"]

print("🎮 Welcome to Rock, Paper, Scissors!")

while True:
    # User input
    user_choice = input("Enter rock, paper, or scissors: ").lower()

    # Check if input is valid
    if user_choice not in choices:
        print("❌ Invalid choice! Try again.")
        continue

    # Computer chooses randomly
    computer_choice = random.choice(choices)

    print(f"\nYou chose: {user_choice}")
    print(f"Computer chose: {computer_choice}")

    # Game logic
    if user_choice == computer_choice:
        print("🤝 It's a tie!")

    elif (
        (user_choice == "rock" and computer_choice == "scissors") or
        (user_choice == "paper" and computer_choice == "rock") or
        (user_choice == "scissors" and computer_choice == "paper")
    ):
        print("🎉 You win!")

    else:
        print("💻 Computer wins!")

    # Ask to play again
    play_again = input("\nDo you want to play again? (yes/no): ").lower()

    if play_again != "yes":
        print("👋 Thanks for playing!")
        break
# Out:
# 🎮 Welcome to Rock, Paper, Scissors!
# Enter rock, paper, or scissors: rock
#
# You chose: rock
# Computer chose: paper
# 💻 Computer wins!
